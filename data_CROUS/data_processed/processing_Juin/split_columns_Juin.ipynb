# %% [markdown]
# # Split Columns données Juin (ENS)

# %% [markdown]
# ## Importation des données

# %%
import numpy as np
import pandas as pd

# %%
filename = 'Resultats_choix_Juin_ENS_cleaned.csv'
df = pd.read_csv(filename, sep=';')
#df = pd.read_csv(f'../../data_clean/{filename}_cleaned.csv', sep=';')
df
# Out:
#      Unnamed: 0 Numéro de formulaire      ENTREE              PLAT   \
# 0             0                  C02  saladesoja  cabillaud+semoule
# 1             1                  C06   saladeriz  cabillaud+semoule
# 2             2                  C04   saucisson      chipo+semoule
# 3             3                  C12         NaN      chipo+semoule
# 4             4                  C07   saladeriz  cabillaud+semoule
# ..          ...                  ...         ...                ...
# 108         108                  B74     endives                NaN
# 109         109                  B80   saucisson      chipo+semoule
# 110         110                  B76   saladeriz         lasagnesvg
# 111         111                  B79    carottes         lasagnesvg
# 112         112                  B78         NaN  cabillaud+semoule
#
#             DESSERT Horodateur  Genre Régime Fréquentation  Faim  ... Aspect  \
# 0             fruit      12:39  Homme    non           1à3   6.0  ...    0.0
# 1               NaN        NaN    NaN    NaN           NaN   NaN  ...    NaN
# 2    moussechocolat        NaN    NaN    NaN           NaN   NaN  ...    NaN
# 3          emmental        NaN    NaN    NaN           NaN   NaN  ...    NaN
# 4            yaourt        NaN    NaN    NaN           NaN   NaN  ...    NaN
# ..              ...        ...    ...    ...           ...   ...  ...    ...
# 108             NaN      13:04  Homme    oui            >3   8.0  ...    3.0
# 109  moussechocolat      13:11  Homme    non           1à3   8.0  ...    6.0
# 110           fruit      13:04  Femme    oui           1à3   6.0  ...    6.0
# 111           fruit        NaN    NaN    NaN           NaN   NaN  ...    NaN
# 112           fruit      13:02  Homme    oui            >3   7.0  ...    7.0
#
#     Attente Convives  Unnamed: 19 Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 0       6.0      C01          NaN         NaN          NaN          NaN
# 1       NaN      NaN          NaN         NaN          NaN          NaN
# 2       NaN      NaN          NaN         NaN          NaN          NaN
# 3       NaN      NaN          NaN         NaN          NaN          NaN
# 4       NaN      NaN          NaN         NaN          NaN          NaN
# ..      ...      ...          ...         ...          ...          ...
# 108     6.0      B73          B76         NaN          NaN          NaN
# 109     7.0      NaN          NaN         NaN          NaN          NaN
# 110     1.0      B73          B74         B75          NaN          NaN
# 111     NaN      NaN          NaN         NaN          NaN          NaN
# 112     7.0      NaN          NaN         NaN          NaN          NaN
#
#     Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0           NaN         NaN         NaN
# 1           NaN         NaN         NaN
# 2           NaN         NaN         NaN
# 3           NaN         NaN         NaN
# 4           NaN         NaN         NaN
# ..          ...         ...         ...
# 108         NaN         NaN         NaN
# 109         NaN         NaN         NaN
# 110         NaN         NaN         NaN
# 111         NaN         NaN         NaN
# 112         NaN         NaN         NaN
#
# [113 rows x 25 columns]

# %% [markdown]
# ## Split

# %% [markdown]
# ### Entrées

# %%
try:
    df[['ENTREE_1', 'ENTREE_2']] = df['ENTREE'].str.split('+', 1, expand=True)
    df.insert(2, 'ENTREE_1', df.pop('ENTREE_1'))
    df.insert(3, 'ENTREE_2', df.pop('ENTREE_2'))
    df.pop('ENTREE')
    split_entree = True
except ValueError as e:
    df['ENTREE_2'] = np.nan
    df.insert(2, 'ENTREE_1', df.pop('ENTREE'))
    df.insert(3, 'ENTREE_2', df.pop('ENTREE_2'))
    split_entree = False
df
# Out:
#      Unnamed: 0 Numéro de formulaire    ENTREE_1  ENTREE_2              PLAT   \
# 0             0                  C02  saladesoja       NaN  cabillaud+semoule
# 1             1                  C06   saladeriz       NaN  cabillaud+semoule
# 2             2                  C04   saucisson       NaN      chipo+semoule
# 3             3                  C12         NaN       NaN      chipo+semoule
# 4             4                  C07   saladeriz       NaN  cabillaud+semoule
# ..          ...                  ...         ...       ...                ...
# 108         108                  B74     endives       NaN                NaN
# 109         109                  B80   saucisson       NaN      chipo+semoule
# 110         110                  B76   saladeriz       NaN         lasagnesvg
# 111         111                  B79    carottes       NaN         lasagnesvg
# 112         112                  B78         NaN       NaN  cabillaud+semoule
#
#             DESSERT Horodateur  Genre Régime Fréquentation  ...  Aspect  \
# 0             fruit      12:39  Homme    non           1à3  ...     0.0
# 1               NaN        NaN    NaN    NaN           NaN  ...     NaN
# 2    moussechocolat        NaN    NaN    NaN           NaN  ...     NaN
# 3          emmental        NaN    NaN    NaN           NaN  ...     NaN
# 4            yaourt        NaN    NaN    NaN           NaN  ...     NaN
# ..              ...        ...    ...    ...           ...  ...     ...
# 108             NaN      13:04  Homme    oui            >3  ...     3.0
# 109  moussechocolat      13:11  Homme    non           1à3  ...     6.0
# 110           fruit      13:04  Femme    oui           1à3  ...     6.0
# 111           fruit        NaN    NaN    NaN           NaN  ...     NaN
# 112           fruit      13:02  Homme    oui            >3  ...     7.0
#
#     Attente Convives Unnamed: 19  Unnamed: 20 Unnamed: 21  Unnamed: 22  \
# 0       6.0      C01         NaN          NaN         NaN          NaN
# 1       NaN      NaN         NaN          NaN         NaN          NaN
# 2       NaN      NaN         NaN          NaN         NaN          NaN
# 3       NaN      NaN         NaN          NaN         NaN          NaN
# 4       NaN      NaN         NaN          NaN         NaN          NaN
# ..      ...      ...         ...          ...         ...          ...
# 108     6.0      B73         B76          NaN         NaN          NaN
# 109     7.0      NaN         NaN          NaN         NaN          NaN
# 110     1.0      B73         B74          B75         NaN          NaN
# 111     NaN      NaN         NaN          NaN         NaN          NaN
# 112     7.0      NaN         NaN          NaN         NaN          NaN
#
#      Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ..           ...         ...         ...
# 108          NaN         NaN         NaN
# 109          NaN         NaN         NaN
# 110          NaN         NaN         NaN
# 111          NaN         NaN         NaN
# 112          NaN         NaN         NaN
#
# [113 rows x 26 columns]

# %%
if split_entree:
    try:
        df[['ENTREE_2', 'ENTREE_3']] = df['ENTREE_2'].str.split('+', 1, expand=True)
        df.insert(3, 'ENTREE_2', df.pop('ENTREE_2'))
        df.insert(4, 'ENTREE_3', df.pop('ENTREE_3'))
    except ValueError as e:
        df['ENTREE_3'] = np.nan
        df.insert(4, 'ENTREE_3', df.pop('ENTREE_3'))
else:
    df['ENTREE_3'] = np.nan
    df.insert(4, 'ENTREE_3', df.pop('ENTREE_3'))
df
# Out:
#      Unnamed: 0 Numéro de formulaire    ENTREE_1  ENTREE_2  ENTREE_3  \
# 0             0                  C02  saladesoja       NaN       NaN
# 1             1                  C06   saladeriz       NaN       NaN
# 2             2                  C04   saucisson       NaN       NaN
# 3             3                  C12         NaN       NaN       NaN
# 4             4                  C07   saladeriz       NaN       NaN
# ..          ...                  ...         ...       ...       ...
# 108         108                  B74     endives       NaN       NaN
# 109         109                  B80   saucisson       NaN       NaN
# 110         110                  B76   saladeriz       NaN       NaN
# 111         111                  B79    carottes       NaN       NaN
# 112         112                  B78         NaN       NaN       NaN
#
#                  PLAT          DESSERT Horodateur  Genre Régime  ... Aspect  \
# 0    cabillaud+semoule           fruit      12:39  Homme    non  ...    0.0
# 1    cabillaud+semoule             NaN        NaN    NaN    NaN  ...    NaN
# 2        chipo+semoule  moussechocolat        NaN    NaN    NaN  ...    NaN
# 3        chipo+semoule        emmental        NaN    NaN    NaN  ...    NaN
# 4    cabillaud+semoule          yaourt        NaN    NaN    NaN  ...    NaN
# ..                 ...             ...        ...    ...    ...  ...    ...
# 108                NaN             NaN      13:04  Homme    oui  ...    3.0
# 109      chipo+semoule  moussechocolat      13:11  Homme    non  ...    6.0
# 110         lasagnesvg           fruit      13:04  Femme    oui  ...    6.0
# 111         lasagnesvg           fruit        NaN    NaN    NaN  ...    NaN
# 112  cabillaud+semoule           fruit      13:02  Homme    oui  ...    7.0
#
#      Attente Convives Unnamed: 19 Unnamed: 20  Unnamed: 21 Unnamed: 22  \
# 0        6.0      C01         NaN         NaN          NaN         NaN
# 1        NaN      NaN         NaN         NaN          NaN         NaN
# 2        NaN      NaN         NaN         NaN          NaN         NaN
# 3        NaN      NaN         NaN         NaN          NaN         NaN
# 4        NaN      NaN         NaN         NaN          NaN         NaN
# ..       ...      ...         ...         ...          ...         ...
# 108      6.0      B73         B76         NaN          NaN         NaN
# 109      7.0      NaN         NaN         NaN          NaN         NaN
# 110      1.0      B73         B74         B75          NaN         NaN
# 111      NaN      NaN         NaN         NaN          NaN         NaN
# 112      7.0      NaN         NaN         NaN          NaN         NaN
#
#      Unnamed: 23  Unnamed: 24 Unnamed: 25
# 0            NaN          NaN         NaN
# 1            NaN          NaN         NaN
# 2            NaN          NaN         NaN
# 3            NaN          NaN         NaN
# 4            NaN          NaN         NaN
# ..           ...          ...         ...
# 108          NaN          NaN         NaN
# 109          NaN          NaN         NaN
# 110          NaN          NaN         NaN
# 111          NaN          NaN         NaN
# 112          NaN          NaN         NaN
#
# [113 rows x 27 columns]

# %% [markdown]
# ### Plats

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Numéro de formulaire', 'ENTREE_1', 'ENTREE_2',
#        'ENTREE_3', 'PLAT ', 'DESSERT', 'Horodateur', 'Genre', 'Régime',
#        'Fréquentation', 'Faim', 'Connaissance entourage',
#        'Influence entourage', 'Influence aspect', 'Quantité', 'Equilibre',
#        'Aspect', 'Attente', 'Convives', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='object')

# %%
try:
    df[['PLAT_1', 'PLAT_2']] = df['PLAT '].str.split('+', 1, expand=True)
    df.insert(6, 'PLAT_1', df.pop('PLAT_1'))
    df.insert(7, 'PLAT_2', df.pop('PLAT_2'))
    df.pop('PLAT ')
    split_plat = True
except ValueError as e:
    df['PLAT_2'] = np.nan
    df.insert(6, 'PLAT_1', df.pop('PLAT '))
    df.insert(7, 'PLAT_2', df.pop('PLAT_2'))
    split_plat = False
df
# Out:
#      Unnamed: 0 Numéro de formulaire    ENTREE_1  ENTREE_2  ENTREE_3  \
# 0             0                  C02  saladesoja       NaN       NaN
# 1             1                  C06   saladeriz       NaN       NaN
# 2             2                  C04   saucisson       NaN       NaN
# 3             3                  C12         NaN       NaN       NaN
# 4             4                  C07   saladeriz       NaN       NaN
# ..          ...                  ...         ...       ...       ...
# 108         108                  B74     endives       NaN       NaN
# 109         109                  B80   saucisson       NaN       NaN
# 110         110                  B76   saladeriz       NaN       NaN
# 111         111                  B79    carottes       NaN       NaN
# 112         112                  B78         NaN       NaN       NaN
#
#          PLAT_1   PLAT_2         DESSERT Horodateur  Genre  ... Aspect  \
# 0     cabillaud  semoule           fruit      12:39  Homme  ...    0.0
# 1     cabillaud  semoule             NaN        NaN    NaN  ...    NaN
# 2         chipo  semoule  moussechocolat        NaN    NaN  ...    NaN
# 3         chipo  semoule        emmental        NaN    NaN  ...    NaN
# 4     cabillaud  semoule          yaourt        NaN    NaN  ...    NaN
# ..          ...      ...             ...        ...    ...  ...    ...
# 108         NaN      NaN             NaN      13:04  Homme  ...    3.0
# 109       chipo  semoule  moussechocolat      13:11  Homme  ...    6.0
# 110  lasagnesvg     None           fruit      13:04  Femme  ...    6.0
# 111  lasagnesvg     None           fruit        NaN    NaN  ...    NaN
# 112   cabillaud  semoule           fruit      13:02  Homme  ...    7.0
#
#     Attente  Convives Unnamed: 19 Unnamed: 20 Unnamed: 21  Unnamed: 22  \
# 0       6.0       C01         NaN         NaN         NaN          NaN
# 1       NaN       NaN         NaN         NaN         NaN          NaN
# 2       NaN       NaN         NaN         NaN         NaN          NaN
# 3       NaN       NaN         NaN         NaN         NaN          NaN
# 4       NaN       NaN         NaN         NaN         NaN          NaN
# ..      ...       ...         ...         ...         ...          ...
# 108     6.0       B73         B76         NaN         NaN          NaN
# 109     7.0       NaN         NaN         NaN         NaN          NaN
# 110     1.0       B73         B74         B75         NaN          NaN
# 111     NaN       NaN         NaN         NaN         NaN          NaN
# 112     7.0       NaN         NaN         NaN         NaN          NaN
#
#     Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN
# ..          ...          ...          ...
# 108         NaN          NaN          NaN
# 109         NaN          NaN          NaN
# 110         NaN          NaN          NaN
# 111         NaN          NaN          NaN
# 112         NaN          NaN          NaN
#
# [113 rows x 28 columns]

# %%
if split_plat:
    try:
        df[['PLAT_2', 'PLAT_3']] = df['PLAT_2'].str.split('+', 1, expand=True)
        df.insert(6, 'PLAT_2', df.pop('PLAT_2'))
        df.insert(7, 'PLAT_3', df.pop('PLAT_3'))
    except ValueError as e:
        df['PLAT_3'] = np.nan
        df.insert(7, 'PLAT_3', df.pop('PLAT_3'))
else:
    df['PLAT_3'] = np.nan
    df.insert(7, 'PLAT_3', df.pop('PLAT_3'))
df
# Out:
#      Unnamed: 0 Numéro de formulaire    ENTREE_1  ENTREE_2  ENTREE_3  \
# 0             0                  C02  saladesoja       NaN       NaN
# 1             1                  C06   saladeriz       NaN       NaN
# 2             2                  C04   saucisson       NaN       NaN
# 3             3                  C12         NaN       NaN       NaN
# 4             4                  C07   saladeriz       NaN       NaN
# ..          ...                  ...         ...       ...       ...
# 108         108                  B74     endives       NaN       NaN
# 109         109                  B80   saucisson       NaN       NaN
# 110         110                  B76   saladeriz       NaN       NaN
# 111         111                  B79    carottes       NaN       NaN
# 112         112                  B78         NaN       NaN       NaN
#
#          PLAT_1   PLAT_2  PLAT_3         DESSERT Horodateur  ... Aspect  \
# 0     cabillaud  semoule     NaN           fruit      12:39  ...    0.0
# 1     cabillaud  semoule     NaN             NaN        NaN  ...    NaN
# 2         chipo  semoule     NaN  moussechocolat        NaN  ...    NaN
# 3         chipo  semoule     NaN        emmental        NaN  ...    NaN
# 4     cabillaud  semoule     NaN          yaourt        NaN  ...    NaN
# ..          ...      ...     ...             ...        ...  ...    ...
# 108         NaN      NaN     NaN             NaN      13:04  ...    3.0
# 109       chipo  semoule     NaN  moussechocolat      13:11  ...    6.0
# 110  lasagnesvg     None     NaN           fruit      13:04  ...    6.0
# 111  lasagnesvg     None     NaN           fruit        NaN  ...    NaN
# 112   cabillaud  semoule     NaN           fruit      13:02  ...    7.0
#
#     Attente Convives  Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0       6.0      C01          NaN         NaN         NaN         NaN
# 1       NaN      NaN          NaN         NaN         NaN         NaN
# 2       NaN      NaN          NaN         NaN         NaN         NaN
# 3       NaN      NaN          NaN         NaN         NaN         NaN
# 4       NaN      NaN          NaN         NaN         NaN         NaN
# ..      ...      ...          ...         ...         ...         ...
# 108     6.0      B73          B76         NaN         NaN         NaN
# 109     7.0      NaN          NaN         NaN         NaN         NaN
# 110     1.0      B73          B74         B75         NaN         NaN
# 111     NaN      NaN          NaN         NaN         NaN         NaN
# 112     7.0      NaN          NaN         NaN         NaN         NaN
#
#      Unnamed: 23 Unnamed: 24  Unnamed: 25
# 0            NaN         NaN          NaN
# 1            NaN         NaN          NaN
# 2            NaN         NaN          NaN
# 3            NaN         NaN          NaN
# 4            NaN         NaN          NaN
# ..           ...         ...          ...
# 108          NaN         NaN          NaN
# 109          NaN         NaN          NaN
# 110          NaN         NaN          NaN
# 111          NaN         NaN          NaN
# 112          NaN         NaN          NaN
#
# [113 rows x 29 columns]

# %% [markdown]
# ### Desserts

# %%
try:
    df[['DESSERT_1', 'DESSERT_2',]] = df['DESSERT'].str.split('+', 1, expand=True)
    df.insert(8, 'DESSERT_1', df.pop('DESSERT_1'))
    df.insert(9, 'DESSERT_2', df.pop('DESSERT_2'))
    df.pop('DESSERT')
    split_dessert = True
except ValueError as e:
    df['DESSERT_2'] = np.nan
    df.insert(8, 'DESSERT_1', df.pop('DESSERT'))
    df.insert(9, 'DESSERT_2', df.pop('DESSERT_2'))
    split_dessert = False
df.iloc[:6,1:14]
# Out:
#      ENTREE_1  ENTREE_2  ENTREE_3     PLAT_1   PLAT_2  PLAT_3       DESSERT_1  \
# 0  saladesoja       NaN       NaN  cabillaud  semoule     NaN           fruit
# 1   saladeriz       NaN       NaN  cabillaud  semoule     NaN             NaN
# 2   saucisson       NaN       NaN      chipo  semoule     NaN  moussechocolat
# 3         NaN       NaN       NaN      chipo  semoule     NaN        emmental
# 4   saladeriz       NaN       NaN  cabillaud  semoule     NaN          yaourt
# 5     endives       NaN       NaN      chipo  semoule     NaN           donut
#
#    DESSERT_2 Horodateur  Genre Régime Fréquentation  Faim
# 0        NaN      12:39  Homme    non           1à3   6.0
# 1        NaN        NaN    NaN    NaN           NaN   NaN
# 2        NaN        NaN    NaN    NaN           NaN   NaN
# 3        NaN        NaN    NaN    NaN           NaN   NaN
# 4        NaN        NaN    NaN    NaN           NaN   NaN
# 5        NaN        NaN    NaN    NaN           NaN   NaN

# %%
if split_dessert:
    try:
        df[['DESSERT_2', 'DESSERT_3']] = df['DESSERT_2'].str.split('+', 1, expand=True)
        df.insert(9, 'DESSERT_2', df.pop('DESSERT_2'))
        df.insert(10, 'DESSERT_3', df.pop('DESSERT_3'))
    except ValueError as e:
        df['DESSERT_3'] = np.nan
        df.insert(10, 'DESSERT_3', df.pop('DESSERT_3'))
else:
        df['DESSERT_3'] = np.nan
        df.insert(10, 'DESSERT_3', df.pop('DESSERT_3'))
df.iloc[:6,1:14]
# Out:
#   Numéro de formulaire    ENTREE_1  ENTREE_2  ENTREE_3     PLAT_1   PLAT_2  \
# 0                  C02  saladesoja       NaN       NaN  cabillaud  semoule
# 1                  C06   saladeriz       NaN       NaN  cabillaud  semoule
# 2                  C04   saucisson       NaN       NaN      chipo  semoule
# 3                  C12         NaN       NaN       NaN      chipo  semoule
# 4                  C07   saladeriz       NaN       NaN  cabillaud  semoule
# 5                  C09     endives       NaN       NaN      chipo  semoule
#
#    PLAT_3       DESSERT_1  DESSERT_2  DESSERT_3 Horodateur  Genre Régime
# 0     NaN           fruit        NaN        NaN      12:39  Homme    non
# 1     NaN             NaN        NaN        NaN        NaN    NaN    NaN
# 2     NaN  moussechocolat        NaN        NaN        NaN    NaN    NaN
# 3     NaN        emmental        NaN        NaN        NaN    NaN    NaN
# 4     NaN          yaourt        NaN        NaN        NaN    NaN    NaN
# 5     NaN           donut        NaN        NaN        NaN    NaN    NaN

# %% [markdown]
# ## Sauvegarde

# %%
df.to_csv('Resultats_choix_Juin_ENS_split.csv', index=False, encoding="cp1252")
# encoding pour le OE majuscule
